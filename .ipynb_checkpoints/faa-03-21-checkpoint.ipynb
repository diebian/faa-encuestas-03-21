# %%
import pandas as pd
from datetime import datetime

# %%
filename = "Percepciones sobre temas de desarrollo rural (Responses) "
version = "202103101015"
source = "./source/" + filename + version  + ".xlsx"
data = pd.read_excel(source)

# data.head()

# %%
data.columns.values
# Out:
# array(['Timestamp', '1.\t¿A qué grupo de edad pertenece?', '2.\tSexo',
#        '3.\tDepartamento donde vive', '4.\tMunicipio donde vive',
#        '5.\tVive en el área:',
#        '6.\tSegún su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive? ',
#        '7.\t¿Sabe lo que es un producto transgénico?',
#        '8.\t ¿Puede compartir su definición de transgénico?',
#        '9.\tEn su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?',
#        '10.\t¿Puede nombrar alguna alternativa de crecimiento de la economía, con menor deforestación y contaminación?',
#        '11. Respuesta A:', '12. Respuesta A:', '13. Respuesta A:',
#        '14.\t¿Actualmente Usted se dedica a la agricultura familiar?',
#        '15. Si se dedica, ¿quisiera continuar haciéndolo?',
#        '16.\tSi no se dedica ¿quisiera hacerlo en un futuro?',
#        '18.\t¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?',
#        '19.\t¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?',
#        '20.\tRespuesta A:', '17.  ¿Por qué?', '11. Respuesta B:',
#        '11. Respuesta C:', '12. Respuesta B:', '12. Respuesta C:',
#        '13. Respuesta B:', '13. Respuesta C:', '20.\tRespuesta B:'],
#       dtype=object)

# %%
# Columns reOrder

columnsTitles = [
    'Timestamp',
    '1.\t¿A qué grupo de edad pertenece?',
    '2.\tSexo',
    '3.\tDepartamento donde vive',
    '4.\tMunicipio donde vive',
    '5.\tVive en el área:',
    '6.\tSegún su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive? ',
    '7.\t¿Sabe lo que es un producto transgénico?',
    '8.\t ¿Puede compartir su definición de transgénico?',
    '9.\tEn su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?',
    '10.\t¿Puede nombrar alguna alternativa de crecimiento de la economía, con menor deforestación y contaminación?',
    '11. Respuesta A:',
    '11. Respuesta B:',
    '11. Respuesta C:',
    '12. Respuesta A:',
    '12. Respuesta B:',
    '12. Respuesta C:',
    '13. Respuesta A:',
    '13. Respuesta B:',
    '13. Respuesta C:',
    '14.\t¿Actualmente Usted se dedica a la agricultura familiar?',
    '15. Si se dedica, ¿quisiera continuar haciéndolo?',
    '16.\tSi no se dedica ¿quisiera hacerlo en un futuro?',
    '17.  ¿Por qué?',
    '18.\t¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?',
    '19.\t¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?',
    '20.\tRespuesta A:',
    '20.\tRespuesta B:'
]

dataReOrder = data.reindex(columns=columnsTitles)

# %%
# dataReOrder.head()

dataRename = dataReOrder.rename(
    columns={
        'Timestamp': 'Fecha de Registro',
        '1.\t¿A qué grupo de edad pertenece?': '1.¿A qué grupo de edad pertenece?',
        '2.\tSexo': '2.Sexo',
        '3.\tDepartamento donde vive': '3.Departamento donde vive',
        '4.\tMunicipio donde vive': '4.Municipio donde vive',
        '5.\tVive en el área:': '5.Vive en el área:',
        '6.\tSegún su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive? ': '6.Según su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive?',
        '7.\t¿Sabe lo que es un producto transgénico?': '7.¿Sabe lo que es un producto transgénico?',
        '8.\t ¿Puede compartir su definición de transgénico?': '8.¿Puede compartir su definición de transgénico?',
        '9.\tEn su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?': '9.En su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?',
        '10.\t¿Puede nombrar alguna alternativa de crecimiento de la economía, con menor deforestación y contaminación?': '10.¿Puede nombrar alguna alternativa de crecimiento de la economía, con menor deforestación y contaminación?',
        '11. Respuesta A:': '11.Respuesta A:',
        '11. Respuesta B:': '11.Respuesta B:',
        '11. Respuesta C:': '11.Respuesta C:',
        '12. Respuesta A:': '12.Respuesta A:',
        '12. Respuesta B:': '12.Respuesta B:',
        '12. Respuesta C:': '12.Respuesta C:',
        '13. Respuesta A:': '13.Respuesta A:',
        '13. Respuesta B:': '13.Respuesta B:',
        '13. Respuesta C:': '13.Respuesta C:',
        '14.\t¿Actualmente Usted se dedica a la agricultura familiar?': '14.¿Actualmente Usted se dedica a la agricultura familiar?',
        '15. Si se dedica, ¿quisiera continuar haciéndolo?': '15.Si se dedica, ¿quisiera continuar haciéndolo?',
        '16.\tSi no se dedica ¿quisiera hacerlo en un futuro?': '16.Si no se dedica ¿quisiera hacerlo en un futuro?',
        '17.  ¿Por qué?': '17.¿Por qué?',
        '18.\t¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?': '18.¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?',
        '19.\t¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?': '19.¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?',
        '20.\tRespuesta A:': '20.Respuesta A:',
        '20.\tRespuesta B:': '20.Respuesta B:'
    })

# %%
dataRename.head()
# Out:
#         Fecha de Registro 1.¿A qué grupo de edad pertenece?  2.Sexo  \
# 0 2021-02-26 16:23:37.451                           29 – 39   Mujer
# 1 2021-02-26 22:13:25.095                           29 – 39   Mujer
# 2 2021-02-26 23:14:33.144                           15 – 28   Mujer
# 3 2021-03-01 13:45:16.002                           15 – 28  Hombre
# 4 2021-03-02 17:52:31.042                           29 – 39   Mujer
#
#   3.Departamento donde vive 4.Municipio donde vive 5.Vive en el área:  \
# 0                    La Paz                 La Paz             Urbana
# 1                    La Paz                La Paz              Urbana
# 2                    La Paz                 La paz             Urbana
# 3                Chuquisaca                  Sucre              Ambos
# 4                      Beni               Trinidad             Urbana
#
#   6.Según su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive?  \
# 0  Actividad minera, Contaminación del aire por v...
# 1               Contaminación del aire por vehículos
# 2  Incendios forestales, Contaminación del aire p...
# 3  Agroquímicos para la producción, Aguas residua...
# 4  Agroquímicos para la producción, Aguas residua...
#
#   7.¿Sabe lo que es un producto transgénico?  \
# 0                                         Sí
# 1                                         Sí
# 2                                         Sí
# 3                                         Sí
# 4                                         Sí
#
#     8.¿Puede compartir su definición de transgénico?  \
# 0  Un organismo modificado genéticamente, una alt...
# 1  Organismo cuyos genes fueron modificado y lo e...
# 2                 Unelemento modificado geneticamete
# 3               dgnzd nc nf mfh czzbf zhnza na zb zb
# 4  Es un ser vivo al que se le ha modificado su g...
#
#   9.En su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?  \
# 0                                En total desacuerdo
# 1                                En total desacuerdo
# 2                                En total desacuerdo
# 3                                      En desacuerdo
# 4                                En total desacuerdo
#
#    ... 13.Respuesta B: 13.Respuesta C:  \
# 0  ...             NaN             NaN
# 1  ...             NaN             NaN
# 2  ...             NaN             NaN
# 3  ...             NaN             NaN
# 4  ...           Avena             NaN
#
#   14.¿Actualmente Usted se dedica a la agricultura familiar?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   15.Si se dedica, ¿quisiera continuar haciéndolo?  \
# 0                                               Sí
# 1                                          Tal vez
# 2                                               Sí
# 3                                               Sí
# 4                                              NaN
#
#   16.Si no se dedica ¿quisiera hacerlo en un futuro?  \
# 0  Porque creo que el reencuentro con la tierra y...
# 1                     Si existieran las condiciones
# 2    Porque estamos en una crisis climatica y social
# 3                             m,ckj,ckm mb,,.vk,ckj,
# 4                                                 Sí
#
#                                         17.¿Por qué?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  para obtener productos saludables y mostrar qu...
#
#   18.¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?  \
# 0  Se merecen todo mi respeto, pues la sobreviven...
# 1                                        Admiración
# 2                                          Valientes
# 3                                 ck,cgk.,hcjkhvjkhb
# 4  son jóvenes que requieren mejorar sus habilida...
#
#   19.¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                                      20.Respuesta A:       20.Respuesta B:
# 0  Podría considerarse el fondo indígena con su e...                   NaN
# 1                                                NaN                   NaN
# 2                                            Ninguna                   NaN
# 3                             gjhmgdhmg ghmghmgchmgc                   NaN
# 4                                            Ley 144  Seguro agropecuario?
#
# [5 rows x 28 columns]

# %%
# remove rows trash
dataRemoveTrash = dataRename.drop(dataRename.index[[0,1,2,3]])
dataRemoveTrash.head()
# Out:
#         Fecha de Registro 1.¿A qué grupo de edad pertenece?  2.Sexo  \
# 4 2021-03-02 17:52:31.042                           29 – 39   Mujer
# 5 2021-03-03 14:45:01.081                           15 – 28  Hombre
# 6 2021-03-03 14:46:46.966                           29 – 39  Hombre
# 7 2021-03-03 14:48:58.723                           29 – 39   Mujer
# 8 2021-03-03 14:50:29.457                           15 – 28   Mujer
#
#   3.Departamento donde vive 4.Municipio donde vive 5.Vive en el área:  \
# 4                      Beni               Trinidad             Urbana
# 5                Chuquisaca                  Sucre             Urbana
# 6                    La Paz              Charazani              Rural
# 7                    Tarija                 Tarija              Ambos
# 8                    La Paz               El Alto              Urbana
#
#   6.Según su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive?  \
# 4  Agroquímicos para la producción, Aguas residua...
# 5  Aguas residuales de las casas, Contaminación d...
# 6  Agroquímicos para la producción, Actividad minera
# 7  Agroquímicos para la producción, Contaminación...
# 8  Agroquímicos para la producción, Actividad min...
#
#   7.¿Sabe lo que es un producto transgénico?  \
# 4                                         Sí
# 5                                         Sí
# 6                                         Sí
# 7                                         Sí
# 8                                         Sí
#
#     8.¿Puede compartir su definición de transgénico?  \
# 4  Es un ser vivo al que se le ha modificado su g...
# 5            Son alimentos genéticamente modificados
# 6            Son alimentos genéticamente modeficados
# 7  Productos alimentarios que fueron producidos c...
# 8                                                NaN
#
#   9.En su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?  \
# 4                                En total desacuerdo
# 5                                        Indiferente
# 6                                En total desacuerdo
# 7                                      En desacuerdo
# 8                                        Indiferente
#
#    ... 13.Respuesta B: 13.Respuesta C:  \
# 4  ...           Avena             NaN
# 5  ...             NaN             NaN
# 6  ...           Mango             NaN
# 7  ...           Mango         Cebolla
# 8  ...             NaN             NaN
#
#   14.¿Actualmente Usted se dedica a la agricultura familiar?  \
# 4                                                 No
# 5                                                 No
# 6                                                 Sí
# 7                                                 No
# 8                                                 No
#
#   15.Si se dedica, ¿quisiera continuar haciéndolo?  \
# 4                                              NaN
# 5                                              NaN
# 6                                               Sí
# 7                                          Tal vez
# 8                                              NaN
#
#   16.Si no se dedica ¿quisiera hacerlo en un futuro?  \
# 4                                                 Sí
# 5                                                 Sí
# 6                                                NaN
# 7                                                 Sí
# 8                                                 No
#
#                                         17.¿Por qué?  \
# 4  para obtener productos saludables y mostrar qu...
# 5  Para aprender a cultivar mis propios alimentos...
# 6  Porque la agricultura familiar es uno de los a...
# 7            Para producir alimentos no transgenicos
# 8                   Prefiero otras áreas de trabajo
#
#   18.¿Qué opinión le merecen los jóvenes, mujeres y hombres, que han optado por quedarse en el campo?  \
# 4  son jóvenes que requieren mejorar sus habilida...
# 5           Han optado por una vida sana y saludable
# 6  La decision es buena por que ellos consumen un...
# 7                                                NaN
# 8                                                NaN
#
#   19.¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?  \
# 4                                                 No
# 5                                                 No
# 6                                                 No
# 7                                                 No
# 8                                                 Sí
#
#                       20.Respuesta A:       20.Respuesta B:
# 4                             Ley 144  Seguro agropecuario?
# 5                                 NaN                   NaN
# 6                                 NaN                   NaN
# 7  El Bono a la apoyo a la produccion      PROSOL en Tarija
# 8                                 NaN                   NaN
#
# [5 rows x 28 columns]

# %%
dateTimeObj  = datetime.now()
version_filenameOrder = dateTimeObj.strftime("%d-%b-%Y %H_%M_%S")
filenameOrder = "./results/Encuestas " + version + ".xlsx"
writer_filenameOrder = pd.ExcelWriter(filenameOrder, engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
dataRemoveTrash.to_excel(writer_filenameOrder, sheet_name='Encuesta GForms')
writer_filenameOrder.save()

# %% [markdown]
# # Process

# %%
# columns name

nameColumns = dataRemoveTrash.columns.values
# selectionColumns = nameColumns[[1, 2, 3, 5, 7, 9, 20, 21, 22, 25]]
selectionColumns = [
    '1.¿A qué grupo de edad pertenece?',
    '2.Sexo',
    '3.Departamento donde vive',
    '5.Vive en el área:',
    '7.¿Sabe lo que es un producto transgénico?',
    '9.En su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?',
    '14.¿Actualmente Usted se dedica a la agricultura familiar?',
    '15.Si se dedica, ¿quisiera continuar haciéndolo?',
    '16.Si no se dedica ¿quisiera hacerlo en un futuro?',
    '19.¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?'
]

print("selection Columns")
print(selectionColumns)

# multipleChoiceColumns = nameColumns[[6]]
multipleChoiceColumns = [
    '6.Según su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive?'
]
print("\nmultiple Choice Columns")
print(multipleChoiceColumns)

# primaryColumns = nameColumns[[1, 2, 3, 4, 5]]
primaryColumns = [
    '1.¿A qué grupo de edad pertenece?',
    '2.Sexo',
    '3.Departamento donde vive',
    '4.Municipio donde vive',
    '5.Vive en el área:'
]
print("\nprimary Columns")
print(primaryColumns)
# Out:
# selection Columns
# ['1.¿A qué grupo de edad pertenece?', '2.Sexo', '3.Departamento donde vive', '5.Vive en el área:', '7.¿Sabe lo que es un producto transgénico?', '9.En su opinión, está de acuerdo en que Bolivia, para crecer económicamente ¿debe continuar ampliando la superficie agropecuaria (frontera agrícola) a costa de los bosques?', '14.¿Actualmente Usted se dedica a la agricultura familiar?', '15.Si se dedica, ¿quisiera continuar haciéndolo?', '16.Si no se dedica ¿quisiera hacerlo en un futuro?', '19.¿Considera que Bolivia cuenta con políticas definidas para el desarrollo de la agricultura familiar?']
#
# multiple Choice Columns
# ['6.Según su percepción, cuál considera Usted que es el principal contaminante del medio ambiente, del agua, de los suelos y otros, en la comunidad/ciudad donde vive?']
#
# primary Columns
# ['1.¿A qué grupo de edad pertenece?', '2.Sexo', '3.Departamento donde vive', '4.Municipio donde vive', '5.Vive en el área:']

# %%
dataToColumns = dataRemoveTrash.copy()
nameColumn = selectionColumns[1]


primaryColumnsFilter = primaryColumns.copy()

if nameColumn in primaryColumns:
    primaryColumnsFilter.remove(nameColumn)
    print(primaryColumnsFilter)

byColumns = primaryColumnsFilter + [nameColumn]
dataFilter = dataToColumns[byColumns]

print("Name column: " + nameColumn)
print("By columns ")
print(byColumns)
print("\nOptions")
df = dataFilter[nameCol].dropna().unique()

for idx, colNew in enumerate(df):
    # options2 = list(dict.fromkeys(options))
    print(colNew)
# Out:
# ['1.¿A qué grupo de edad pertenece?', '3.Departamento donde vive', '4.Municipio donde vive', '5.Vive en el área:']
# Name column: 2.Sexo
# By columns
# ['1.¿A qué grupo de edad pertenece?', '3.Departamento donde vive', '4.Municipio donde vive', '5.Vive en el área:', '2.Sexo']
#
# Options
# Mujer
# Hombre

# %% [markdown]
# # Columns explode

# %%
writer_byColumns = pd.ExcelWriter("./results/porColumnas.xlsx", engine="xlsxwriter")
sheet_name = str(nameColumn[:28])
dataFilter.to_excel(writer_byColumns, sheet_name=sheet_name)
    
writer_byColumns.save()
